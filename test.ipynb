# %%
import pandas as pd

test = pd.read_csv("project01/test.csv")
games = pd.read_csv("project01/games.csv")
players = pd.read_csv("project01/players.csv")

# %%
games["winby"] = games["home_team_goal"] - games["away_team_goal"]
games["winner"] = games["winby"].map(lambda w: 0 if w >= 0 else 1)

# %%
games
# Out:
#        year  home_team_id  away_team_id  home_player_1  home_player_2  \
# 0      2009           135           146         2086.0         2379.0
# 1      2009           136            94         1542.0            NaN
# 2      2009           134           140         1316.0         1873.0
# 3      2009           143           149         8921.0         1853.0
# 4      2009           199           224         1732.0         1695.0
# ...     ...           ...           ...            ...            ...
# 19322  2014           124            55         7174.0         3680.0
# 19323  2014           241           242          667.0         3315.0
# 19324  2014           235           129         3303.0          695.0
# 19325  2014             3           123         3138.0         6465.0
# 19326  2014           229           236         8526.0         3289.0
#
#        home_player_3  home_player_4  home_player_5  home_player_6  \
# ...

# %%
test
# Out:
#      home_team_id  away_team_id  home_player_1  home_player_2  home_player_3  \
# 0           239.0         144.0         6533.0         1775.0         6612.0
# 1           117.0         246.0          454.0         6681.0         4859.0
# 2            92.0           NaN         8439.0         9242.0         5548.0
# 3            71.0           NaN         3801.0         2931.0         8648.0
# 4           182.0         176.0         2335.0            NaN         6183.0
# ..            ...           ...            ...            ...            ...
# 995         111.0         204.0         4271.0         1926.0         4880.0
# 996         224.0         131.0         1912.0         4825.0         1841.0
# 997         261.0          69.0         4372.0         5610.0         8130.0
# 998         143.0         135.0         1711.0         5628.0         7341.0
# 999         129.0           NaN          642.0         4086.0         8880.0
#
# ...

# %%
training_set = games.dropna()
training_set["winby"] = training_set["home_team_goal"] - training_set["away_team_goal"]
training_set
# Out:
# C:\Users\16044\AppData\Local\Temp\ipykernel_20116\3720182764.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   training_set["winby"] = training_set["home_team_goal"] - training_set["away_team_goal"]
#        year  home_team_id  away_team_id  home_player_1  home_player_2  \
# 2      2009           134           140         1316.0         1873.0
# 3      2009           143           149         8921.0         1853.0
# 4      2009           199           224         1732.0         1695.0
# 7      2009            94           224         1747.0         1314.0
# 11     2009             6           143         2377.0          798.0
# ...     ...           ...           ...            ...            ...
# ...

# %%
players
# Out:
#         player_id  overall_rating  potential preferred_foot  \
# 0            4691            61.0       65.0          right
# 1            7086            71.0       77.0           left
# 2            7086            71.0       77.0           left
# 3            7086            70.0       77.0           left
# 4            7086            70.0       79.0           left
# ...           ...             ...        ...            ...
# 127301       2507            83.0       85.0          right
# 127302       2507            78.0       80.0          right
# 127303       2507            77.0       80.0          right
# 127304       2507            78.0       81.0          right
# 127305       2507            80.0       81.0          right
#
#        attacking_work_rate defensive_work_rate  crossing  year
# 0                   medium              medium      48.0  2007
# 1                   medium              medium      78.0  2014
# ...

# %%
import numpy as np


player_avg_overall_rating = dict(players[["player_id", "overall_rating"]].groupby("player_id").agg(np.mean))
player_avg_overall_rating_dict = player_avg_overall_rating["overall_rating"].to_dict()
player_avg_overall_rating_dict
# Out:
# {'overall_rating': player_id
# 1       67.428571
# 2       68.000000
# 3       76.074074
# 4       71.166667
# 5       68.375000
#           ...
# 9424    74.000000
# 9425    73.200000
# 9426    82.500000
# 9427    68.821429
# 9428    66.400000
# Name: overall_rating, Length: 9428, dtype: float64}
# C:\Users\16044\AppData\Local\Temp\ipykernel_20116\1841737878.py:4: FutureWarning: The provided callable <function mean at 0x0000011227D11300> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   player_avg_overall_rating = dict(players[["player_id", "overall_rating"]].groupby("player_id").agg(np.mean))
# {1: 67.42857142857143,
#  2: 68.0,
#  3: 76.07407407407408,
#  4: 71.16666666666667,
#  5: 68.375,
#  6: 62.63636363636363,
#  7: 60.916666666666664,
#  8: 64.2,
#  9: 64.25,
#  10: 57.4,
#  11: 59.0,
#  12: 61.0,
#  13: 60.8,
#  14: 56.0,
# ...
